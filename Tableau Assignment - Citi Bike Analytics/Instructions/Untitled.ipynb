# %%
from bs4 import BeautifulSoup
import pandas as pd
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
from os import environ
from os import environ

# Utility to write data to redshift quickly

import pandas_redshift as pr
import pandas as pd
import settings # Axial DB Settings
from axial.factory.db_engine_factory import get_dwp_engine
import datetime
from collections import OrderedDict
from os import environ
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-806daa6e3439> in <module>
#       9 # Utility to write data to redshift quickly
#      10
# ---> 11 import pandas_redshift as pr
#      12 import pandas as pd
#      13 import settings # Axial DB Settings
#
# ModuleNotFoundError: No module named 'pandas_redshift'
